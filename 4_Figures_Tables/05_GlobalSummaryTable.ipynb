# %%
# ============================================================
# Global Summary Table — Country-level Aggregation
# RF city points → country summary (area + population)
#
# Inputs (relative to repo root):
#   - 4_Figures_Tables/AllCities_Points.gpkg
#   - 4_Figures_Tables/country_ISOcodes.csv
#
# Output (written once, then manually cleaned):
#   - 4_Figures_Tables/Tables/CountrySummary_RF_raw.csv
#
# NOTE:
#   The first run may contain rows with missing ISO3 codes.
#   These ISO codes are checked and filled manually.
#   The cleaned, final table is then saved/uploaded as:
#   - 4_Figures_Tables/Tables/CountrySummary_RF.csv
# ============================================================

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
# -------- CONFIG — portable repo-root detection --------
REPO_ROOT = Path.cwd()
while REPO_ROOT.name != "citysegmentdeprivation" and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent

POINTS_GPKG = REPO_ROOT / "4_Figures_Tables" / "AllCities_Points.gpkg"
ISO_CSV     = REPO_ROOT / "4_Figures_Tables" / "country_ISOcodes.csv"
TABLE_DIR   = REPO_ROOT / "4_Figures_Tables" / "Tables"
TABLE_DIR.mkdir(parents=True, exist_ok=True)

# Raw output from this script (before manual ISO fixes)
OUT_CSV_RAW = TABLE_DIR / "CountrySummary_RF_raw.csv"

print("📂 Points GPKG :", POINTS_GPKG)
print("📂 ISO table   :", ISO_CSV)
print("📂 Out (raw)   :", OUT_CSV_RAW)

# -------- LOAD DATA --------
print("\n📥 Loading files...")
gdf = gpd.read_file(POINTS_GPKG)
iso_df = pd.read_csv(ISO_CSV)

# Normalize country names for matching
gdf["CTR_MN_NM_norm"] = gdf["CTR_MN_NM"].str.lower().str.strip()
iso_df["Country_norm"] = iso_df["Country"].str.lower().str.strip()

# %%
# -------- AGGREGATE BY COUNTRY --------
agg = (
    gdf.groupby("CTR_MN_NM_norm")
      .agg(
          Country=("CTR_MN_NM", "first"),
          Region=("REG1_GHSL", "first"),
          Total_Area_km2=("AREA_TOTAL", lambda x: np.sum(x) / 1e6),
          Deprived_Area_km2=("AREA_DEPRIVED", lambda x: np.sum(x) / 1e6),
          Total_Pop_M=("POP_TOTAL", lambda x: np.sum(x) / 1e6),
          Deprived_Pop_M=("DEPRIVED_POP", lambda x: np.sum(x) / 1e6),
      )
      .reset_index(drop=True)
)

# -------- MERGE ISO CODES --------
agg["Country_norm"] = agg["Country"].str.lower().str.strip()

agg = (
    agg.merge(
        iso_df[["Country_norm", "ISO"]],
        how="left",
        on="Country_norm"
    )
    .drop(columns="Country_norm")
)

# Reorder columns
agg = agg[[
    "Region", "ISO", "Country",
    "Total_Area_km2", "Deprived_Area_km2",
    "Total_Pop_M", "Deprived_Pop_M"
]]

# -------- SAVE RAW OUTPUT --------
agg.to_csv(OUT_CSV_RAW, index=False, float_format="%.3f")

print(f"\n✅ Saved RAW country-level summary to:\n{OUT_CSV_RAW}")
print(f"🌍 Total countries summarized: {len(agg)}")

# List countries missing ISO (to be fixed manually)
missing_iso = agg[agg["ISO"].isna()]
if not missing_iso.empty:
    print("\n⚠️ Countries missing ISO code (to fix manually):")
    print(missing_iso[["Country", "Region"]].to_string(index=False))
else:
    print("\n✅ All countries have ISO codes.")

# Quick preview
print("\nSample rows:")
print(agg.head(10).to_string(index=False))
# Out:
# ✅ Saved RAW country-level summary to:
# D:\VSG\DIRTY_MODEL\February2026\csmd_model_v2\4_Figures_Tables\Tables\CountrySummary_RF_raw.csv
# 🌍 Total countries summarized: 103
#
# ⚠️ Countries missing ISO code (to fix manually):
#                          Country                          Region
#                     Burkina Faso                          Africa
#         Central African Republic                          Africa
#                       Costa Rica Latin America and the Caribbean
#                    Côte d'Ivoire                          Africa
# Democratic Republic of the Congo                          Africa
#               Dominican Republic Latin America and the Caribbean
#                      El Salvador Latin America and the Caribbean
#                Equatorial Guinea                          Africa
#                    Guinea-Bissau                          Africa
#                      North Korea                            Asia
#                Republic of Congo                          Africa
#                     Sierra Leone                          Africa
#                     South Africa                          Africa
#                      South Sudan                          Africa
#                        Sri Lanka                            Asia
#                      Timor-Leste                            Asia
#                   Western Sahara                          Africa
#
# Sample rows:
#                          Region ISO     Country  Total_Area_km2  Deprived_Area_km2  Total_Pop_M  Deprived_Pop_M
#                            Asia AFG Afghanistan      851.926552          19.763253    11.517774        0.803736
#                          Africa DZA     Algeria     2962.645547         111.169848    19.325879        2.148402
#                          Africa AGO      Angola     1751.967460         558.548649    20.650830       12.619480
# Latin America and the Caribbean ARG   Argentina     5135.190998         352.042920    28.393329        2.023375
#                            Asia BGD  Bangladesh    13117.427334         283.369655    68.542720       14.028884
# Latin America and the Caribbean BLZ      Belize       16.906662           5.624981     0.073861        0.034496
#                          Africa BEN       Benin      696.462600          98.489524     4.673286        1.395721
# Latin America and the Caribbean BOL     Bolivia      943.765414         121.515300     6.537426        0.938797
#                          Africa BWA    Botswana      196.110030          13.174819     0.549454        0.058715
# Latin America and the Caribbean BRA      Brazil    20372.207021         896.409141   117.923300       14.346481

# %%
# ----------------------------------------------------------------
# After running this script once:
#   1. Open CountrySummary_RF_raw.csv
#   2. Manually fill / correct any missing ISO codes
#      (countries with special characters or multi-word names
#       frequently fail to match the ISO lookup table).
#   3. Save the corrected file as:
#        4_Figures_Tables/Tables/CountrySummary_RF.csv
#
# Known reproducibility limitation:
#   This manual ISO correction step is not automated. The raw output
#   (CountrySummary_RF_raw.csv) is produced by this notebook; the
#   manually corrected final table (CountrySummary_RF.csv) is committed
#   to the repository. Future cleanup should replace the manual step
#   with a lookup from a comprehensive ISO3 reference table.
# ----------------------------------------------------------------
