# %%
# ===============================================================
# Figure 3 — Country lollipop plots + city-size inset bar charts
#
# Inputs (relative to repo root):
#   - 2_modelling/02_application/summary_statistics/city_deprivation_with_sizeclass_80pct.csv
#   - 4_Figures_Tables/country_ISOcodes.csv
#
# Outputs (PDF, vector):
#   - 4_Figures_Tables/Figures/Figure3_Lollipop_Regional_Deprivation.pdf
#   - 4_Figures_Tables/Figures/Figure3_Africa_CitySize.pdf
#   - 4_Figures_Tables/Figures/Figure3_Asia_CitySize.pdf
#   - 4_Figures_Tables/Figures/Figure3_LAC_CitySize.pdf
#   - 4_Figures_Tables/Figures/Figure3_CitySize_2x2.pdf
# ===============================================================

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
# ---------------------------------------------------------------
# 1) Paths — portable repo-root detection
# ---------------------------------------------------------------
REPO_ROOT = Path.cwd()
while REPO_ROOT.name != "citysegmentdeprivation" and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent

CITY_PATH = REPO_ROOT / "2_modelling" / "02_application" / "summary_statistics" / "city_deprivation_with_sizeclass_80pct.csv"
ISO_PATH  = REPO_ROOT / "4_Figures_Tables" / "country_ISOcodes.csv"
FIG_DIR   = REPO_ROOT / "4_Figures_Tables" / "Figures"
FIG_DIR.mkdir(parents=True, exist_ok=True)

print("City file:", CITY_PATH)
print("ISO file :", ISO_PATH)
print("Figures  :", FIG_DIR)

for p in [CITY_PATH, ISO_PATH]:
    if not p.exists():
        raise FileNotFoundError(f"Missing input file: {p}")

# %%
# ---------------------------------------------------------------
# 2) Load data + cleaning
# ---------------------------------------------------------------
city_df = pd.read_csv(CITY_PATH)
iso_df  = pd.read_csv(ISO_PATH)

required_city_cols = {"Region", "Country", "TotalPop", "DeprivedPop", "CitySizeClass"}
missing = required_city_cols - set(city_df.columns)
if missing:
    raise KeyError(f"city_df missing required columns: {sorted(missing)}")

required_iso_cols = {"Country", "ISO"}
missing_iso = required_iso_cols - set(iso_df.columns)
if missing_iso:
    raise KeyError(f"iso_df missing required columns: {sorted(missing_iso)}")

# numeric coercion
for col in ["TotalPop", "DeprivedPop"]:
    city_df[col] = pd.to_numeric(city_df[col], errors="coerce")

city_df = city_df.dropna(subset=["Region", "Country", "TotalPop", "DeprivedPop"])
city_df = city_df[city_df["TotalPop"] > 0]
city_df = city_df[city_df["DeprivedPop"] >= 0]

# %%
# ---------------------------------------------------------------
# 3) Country aggregation + ISO merge
# ---------------------------------------------------------------
country_df = (
    city_df.groupby(["Region", "Country"], as_index=False)
    .agg(TotalPop=("TotalPop", "sum"),
         DeprivedPop=("DeprivedPop", "sum"))
)
country_df["PctDeprived"] = (country_df["DeprivedPop"] / country_df["TotalPop"]) * 100

country_df = country_df.merge(iso_df[["Country", "ISO"]], on="Country", how="left")

missing_iso_n = int(country_df["ISO"].isna().sum())
if missing_iso_n:
    print(f"⚠️ Warning: {missing_iso_n} countries missing ISO code. Falling back to Country names on y-axis.")
    country_df["ISO"] = country_df["ISO"].fillna(country_df["Country"])

global_max_deprived = float(country_df["DeprivedPop"].max()) if len(country_df) else 1.0
global_max_deprived = max(global_max_deprived, 1.0)

# Manual fine-tuning offsets in percentage points (for labels of abs. deprived pop)
label_offsets = {
    "NGA": 2.5, "EGY": 2.5, "COD": 2.5,
    "IND": 2.5, "PAK": 8.5, "BGD": 2.5,
    "BRA": 3.0, "COL": 3.0, "MEX": 2.5,
}

# %%
# ---------------------------------------------------------------
# 4) Style (Nature-friendly vector PDF)
# ---------------------------------------------------------------
mpl.rcParams["font.family"] = "DejaVu Sans"
mpl.rcParams["pdf.fonttype"] = 42   # editable TrueType fonts in PDF
mpl.rcParams["ps.fonttype"]  = 42

# %%
# ---------------------------------------------------------------
# 5) Lollipop plotting function (per region)
# ---------------------------------------------------------------
def plot_lollipop(ax, sub, region_name, add_legend=False, color="#d62728"):
    if sub.empty:
        ax.text(0.5, 0.5, f"No data for {region_name}", ha="center", va="center")
        ax.set_axis_off()
        return

    sub = sub.sort_values("PctDeprived", ascending=False).copy()

    # Region average (pop-weighted)
    region_avg = (sub["DeprivedPop"].sum() / sub["TotalPop"].sum()) * 100

    # Normalize dot sizes (sqrt scaling, consistent with global max)
    sizes = np.sqrt(sub["DeprivedPop"].to_numpy()) / np.sqrt(global_max_deprived) * 400
    sizes = np.clip(sizes, 10, 600)

    # Stems
    ax.hlines(
        y=sub["ISO"],
        xmin=0,
        xmax=sub["PctDeprived"],
        color="lightgrey",
        linewidth=1,
        zorder=1,
    )

    # Dots
    ax.scatter(
        sub["PctDeprived"],
        sub["ISO"],
        s=sizes,
        color=color,
        alpha=0.8,
        zorder=3,
        linewidth=0,
    )

    # Region average line
    ax.axvline(region_avg, color="navy", linestyle="--", linewidth=1, zorder=2)

    # Place avg label at top row (robust for categorical y)
    top_label = sub["ISO"].iloc[-1]
    ax.text(
        region_avg + 0.8,
        top_label,
        f"Region Avg: {region_avg:.1f}%",
        color="navy",
        fontsize=11,
        va="center",
        ha="left",
    )

    # --- Highlight top 3 by % deprived (percent labels) ---
    top3_pct = sub.head(3)
    for _, row in top3_pct.iterrows():
        ax.text(
            float(row["PctDeprived"]) + 2.0,
            row["ISO"],
            f"{float(row['PctDeprived']):.1f}%",
            va="center",
            fontsize=10,
            color="black",
        )

    # --- Highlight top 3 by absolute deprived population (millions) ---
    top3_abs = sub.nlargest(3, "DeprivedPop")
    for _, row in top3_abs.iterrows():
        iso = str(row["ISO"])
        offset_x = label_offsets.get(iso, 2.0)
        ax.text(
            float(row["PctDeprived"]) + offset_x,
            row["ISO"],
            f"{float(row['DeprivedPop']) / 1e6:.0f}M",
            va="center",
            ha="left",
            fontsize=11,
            color="darkred",
            fontweight="bold",
        )

    # Formatting
    ax.set_title(
        f"Share of population in deprived segments by country — {region_name}",
        fontsize=11,
        fontweight="bold",
    )
    ax.set_xlabel("Population in deprived segments (%)")
    ax.set_ylabel("")
    ax.grid(axis="x", linestyle=":", alpha=0.3)
    ax.set_xlim(0, 82)

    # Add dot size legend only once (Africa panel)
    if add_legend:
        for pop in [1e6, 10e6, 50e6]:  # 1M, 10M, 50M deprived
            ax.scatter(
                [],
                [],
                s=np.sqrt(pop) / np.sqrt(global_max_deprived) * 400,
                color=color,
                alpha=0.6,
                label=f"{int(pop / 1e6)}M",
            )
        ax.legend(
            title="Population in deprived\nsegments (millions)",
            loc="upper right",
            fontsize=9,
            title_fontsize=10,
            frameon=False,
        )

# %%
# ---------------------------------------------------------------
# 6) Main lollipop figure (Africa, Asia, LAC)
# ---------------------------------------------------------------
fig = plt.figure(figsize=(14, 12))
gs = fig.add_gridspec(
    2,
    2,
    width_ratios=[1.1, 1],
    height_ratios=[1.2, 0.8],
    #wspace=0.15,
)

ax_africa = fig.add_subplot(gs[:, 0])
plot_lollipop(
    ax_africa,
    country_df[country_df["Region"] == "Africa"],
    "Africa",
    #add_legend=True,
)

ax_asia = fig.add_subplot(gs[0, 1])
plot_lollipop(
    ax_asia,
    country_df[country_df["Region"] == "Asia"],
    "Asia",
    add_legend=True,
)

ax_lac = fig.add_subplot(gs[1, 1])
plot_lollipop(
    ax_lac,
    country_df[country_df["Region"] == "Latin America and the Caribbean"],
    "LAC",
)

plt.tight_layout()

outfile_lollipop_pdf = FIG_DIR / "Figure3_Lollipop_Regional_Deprivation.pdf"
outfile_lollipop_png = FIG_DIR / "Figure3_Lollipop_Regional_Deprivation.png"
fig.savefig(outfile_lollipop_pdf, format="pdf", bbox_inches="tight")
fig.savefig(outfile_lollipop_png, format="png", dpi=600, bbox_inches="tight")
print(f"✅ Saved lollipop figure to: {outfile_lollipop_pdf}")

plt.show()

# %%
# ---------------------------------------------------------------
# 7) City-size plots (PDF)
# ---------------------------------------------------------------
def plot_region_citysize(df, region_name, filename=None):
    region_cities = df[df["Region"] == region_name].copy()
    if region_cities.empty:
        print(f"⚠️ No city rows for region: {region_name}")
        return

    size_summary = (
        region_cities.groupby("CitySizeClass", as_index=False)
        .agg(
            TotalPop=("TotalPop", "sum"),
            DeprivedPop=("DeprivedPop", "sum"),
        )
    )
    size_summary = size_summary[size_summary["TotalPop"] > 0]

    size_summary["NonDeprivedPop"] = size_summary["TotalPop"] - size_summary["DeprivedPop"]
    size_summary["DeprivedPct"] = (size_summary["DeprivedPop"] / size_summary["TotalPop"]) * 100
    size_summary["NonDeprivedPct"] = 100 - size_summary["DeprivedPct"]

    order = ["Small", "Medium", "Large", "Very large", "Megacity"]
    size_summary["CitySizeClass"] = pd.Categorical(
        size_summary["CitySizeClass"],
        categories=order,
        ordered=True,
    )
    size_summary = size_summary.sort_values("CitySizeClass")

    fig2, ax = plt.subplots(figsize=(6, 4))

    bars1 = ax.barh(
        size_summary["CitySizeClass"],
        size_summary["NonDeprivedPct"],
        color="lightgrey",
        label="Non-deprived",
        height=0.8,
    )
    bars2 = ax.barh(
        size_summary["CitySizeClass"],
        size_summary["DeprivedPct"],
        left=size_summary["NonDeprivedPct"],
        color="#d62728",
        label="Deprived",
        height=0.8,
    )

    for bar, pct, absval, base in zip(
        bars2,
        size_summary["DeprivedPct"],
        size_summary["DeprivedPop"] / 1e6,
        size_summary["NonDeprivedPct"],
    ):
        if float(pct) > 2:
            ax.text(
                float(base) + float(pct) / 2,
                bar.get_y() + bar.get_height() / 2,
                f"{float(pct):.1f}%\n({float(absval):.0f}M)",
                ha="center",
                va="center",
                color="white",
                fontsize=10,
                fontweight="bold",
            )

    ax.set_xlabel("Population share (%)", fontsize=11)
    ax.set_xlim(0, 100)
    ax.set_title("Population share by city size", fontsize=12, fontweight="bold")
    ax.tick_params(axis="y", labelsize=11)
    ax.grid(axis="x", linestyle=":", alpha=0.4)

    ax.legend(
        loc="lower left",
        frameon=True,
        framealpha=1,
        edgecolor="black",
        fancybox=False,
        fontsize=9,
        title_fontsize=10,
    )

    plt.tight_layout()

    if filename:
        fig2.savefig(filename, format="pdf", bbox_inches="tight")
        print(f"✅ Saved city-size figure to: {filename}")

    plt.show()

plot_region_citysize(city_df, "Africa", filename=FIG_DIR / "Figure3_Africa_CitySize.pdf")
plot_region_citysize(city_df, "Asia", filename=FIG_DIR / "Figure3_Asia_CitySize.pdf")
plot_region_citysize(city_df, "Latin America and the Caribbean", filename=FIG_DIR / "Figure3_LAC_CitySize.pdf")

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# ---------------------------------------------------------------
# 7) City-size plots (2x2 panel: 3 regions + legend panel)
# ---------------------------------------------------------------
def plot_region_citysize_on_ax(ax, df, region_name, show_title=True):
    region_cities = df[df["Region"] == region_name].copy()
    if region_cities.empty:
        ax.text(0.5, 0.5, f"No data: {region_name}", ha="center", va="center")
        ax.set_axis_off()
        return

    size_summary = (
        region_cities.groupby("CitySizeClass", as_index=False)
        .agg(
            TotalPop=("TotalPop", "sum"),
            DeprivedPop=("DeprivedPop", "sum"),
        )
    )
    size_summary = size_summary[size_summary["TotalPop"] > 0].copy()

    size_summary["NonDeprivedPop"] = size_summary["TotalPop"] - size_summary["DeprivedPop"]
    size_summary["DeprivedPct"] = (size_summary["DeprivedPop"] / size_summary["TotalPop"]) * 100
    size_summary["NonDeprivedPct"] = 100 - size_summary["DeprivedPct"]

    order = ["Small", "Medium", "Large", "Very large", "Megacity"]
    size_summary["CitySizeClass"] = pd.Categorical(
        size_summary["CitySizeClass"], categories=order, ordered=True
    )
    size_summary = size_summary.sort_values("CitySizeClass")

    # Stacked horizontal bars
    bars1 = ax.barh(
        size_summary["CitySizeClass"],
        size_summary["NonDeprivedPct"],
        color="lightgrey",
        label="Non-deprived",
        height=0.8,
    )
    bars2 = ax.barh(
        size_summary["CitySizeClass"],
        size_summary["DeprivedPct"],
        left=size_summary["NonDeprivedPct"],
        color="#d62728",
        label="Deprived",
        height=0.8,
    )

    # Labels on deprived portion
    for bar, pct, absval, base in zip(
        bars2,
        size_summary["DeprivedPct"],
        size_summary["DeprivedPop"] / 1e6,
        size_summary["NonDeprivedPct"],
    ):
        if float(pct) > 2:
            ax.text(
                float(base) + float(pct) / 2,
                bar.get_y() + bar.get_height() / 2,
                f"{float(pct):.1f}%\n({float(absval):.0f}M)",
                ha="center",
                va="center",
                color="white",
                fontsize=10,
                fontweight="bold",
            )

    # Formatting
    if show_title:
        ax.set_title(region_name, fontsize=12, fontweight="bold")

    ax.set_xlim(0, 100)
    ax.set_xlabel("Population share (%)", fontsize=11)
    ax.tick_params(axis="y", labelsize=11)
    ax.grid(axis="x", linestyle=":", alpha=0.4)

    # IMPORTANT: no per-axes legend
    # Return handles if you want to reuse them
    return bars1, bars2


# ---------------------------------------------------------------
# Build 2x2 figure: Africa, Asia, LAC, Legend
# ---------------------------------------------------------------
regions = [
    ("Africa", "Africa"),
    ("Asia", "Asia"),
    ("Latin America and the Caribbean", "Latin America & Caribbean"),
]

fig, axes = plt.subplots(2, 2, figsize=(12, 8), constrained_layout=True)

ax_africa = axes[0, 0]
ax_asia   = axes[0, 1]
ax_lac    = axes[1, 0]
ax_leg    = axes[1, 1]

plot_region_citysize_on_ax(ax_africa, city_df, regions[0][0])
plot_region_citysize_on_ax(ax_asia,   city_df, regions[1][0])
plot_region_citysize_on_ax(ax_lac,    city_df, regions[2][0])

# Legend panel (bottom-right)
ax_leg.set_axis_off()

# --- LEFT SIDE: Color legend ---
legend_handles = [
    Patch(facecolor="lightgrey", edgecolor="none", label="Non-deprived"),
    Patch(facecolor="#d62728", edgecolor="none", label="Deprived"),
]

leg = ax_leg.legend(
    handles=legend_handles,
    loc="center left",
    bbox_to_anchor=(0.05, 0.55),
    frameon=True,
    framealpha=1,
    edgecolor="black",
    fancybox=False,
    fontsize=15,
    title="Legend",
    title_fontsize=16,
)

# --- RIGHT SIDE: City-size definitions ---
citysize_text = (
    "City size classes:\n\n"
    "Small (< 500k)\n"
    "Medium (500k–1M)\n"
    "Large (1–5M)\n"
    "Very large (5–10M)\n"
    "Megacity (> 10M)"
)

ax_leg.text(
    0.60,      # push to right half
    0.55,
    citysize_text,
    ha="left",
    va="center",
    fontsize=15,
)

# Optional overall title
fig.suptitle("Population share by city size", fontsize=14, fontweight="bold")

# ---------------------------------------------------------
# EXPORT (PDF + PNG 600 DPI)
# ---------------------------------------------------------
pdf_path = FIG_DIR / "Figure3_CitySize_2x2.pdf"
png_path = FIG_DIR / "Figure3_CitySize_2x2.png"

fig.savefig(pdf_path, format="pdf", bbox_inches="tight")
fig.savefig(png_path, format="png", dpi=600, bbox_inches="tight")

print(f"✅ Saved PDF: {pdf_path}")
print(f"✅ Saved PNG (600 dpi): {png_path}")

plt.show()
