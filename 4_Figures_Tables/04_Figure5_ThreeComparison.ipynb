# %%
# ==============================================================
# Figure 5 — Combined 3×3 comparison (SSI, MN, WRI vs CSD, τ = 0.1)
#
# Inputs:
#   - 3_comparitive_analysis/SSI/Pooled_Results/ssi_rf_country_metrics.csv
#     (tracked in repository)
#   - data_external/zenodo/mn_comparison_files/{country}/{country}_segments_mnlabels_k3_maj10.gpkg
#     (large; not in GitHub — produced by 3_comparitive_analysis/MN/01_MN_Data_and_Labels.ipynb)
#   - data_external/zenodo/wri_per_country_outputs/{country}/{country}_wri_vs_rf_threshold_sweep_country.csv
#     (large; not in GitHub — produced by 3_comparitive_analysis/WRI/03_WRI_PerCountry_Metrics.ipynb)
#
# The "summary" block for the right-hand metric bars is HARD-CODED
# but derived from the following global summary tables:
#   - 3_comparitive_analysis/SSI/Pooled_Results/
#       rf_ssi_population_summary_GLOBAL_rule_threshold_table_millions.csv
#   - 3_comparitive_analysis/MN/Outputs/
#       mn_rf_summary_segments_population_GLOBAL_k_tau_table_millions.csv
#   - 3_comparitive_analysis/WRI/Outputs/
#       wri_rf_population_summary_GLOBAL_rule_threshold_table_millions.csv
#
# Output (PDF, vector):
#   - 4_Figures_Tables/Figures/Figure5_ThreeComparisons_withreg.pdf
# ==============================================================

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import geopandas as gpd
from sklearn.metrics import precision_score, recall_score, f1_score
from matplotlib.gridspec import GridSpec

# %%
# --------------------------------------------------------------
# 1️⃣ Paths — portable repo-root detection
# --------------------------------------------------------------
REPO_ROOT = Path.cwd()
while REPO_ROOT.name != "citysegmentdeprivation" and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent

DATA_EXTERNAL = REPO_ROOT / "data_external"
ZENODO_DATA   = DATA_EXTERNAL / "zenodo"

SSI_CSV  = REPO_ROOT / "3_comparitive_analysis" / "SSI" / "Pooled_Results" / "ssi_rf_country_metrics.csv"
MN_ROOT  = ZENODO_DATA / "mn_comparison_files"
WRI_ROOT = ZENODO_DATA / "wri_per_country_outputs"

FIG_OUT_DIR = REPO_ROOT / "4_Figures_Tables" / "Figures"
FIG_OUT_DIR.mkdir(parents=True, exist_ok=True)

print("SSI metrics CSV :", SSI_CSV)
print("MN comparison   :", MN_ROOT)
print("WRI outputs     :", WRI_ROOT)
print("Figure outdir   :", FIG_OUT_DIR)

if not SSI_CSV.exists():
    raise FileNotFoundError(f"Missing SSI CSV: {SSI_CSV}")
if not MN_ROOT.exists():
    raise FileNotFoundError(f"Missing MN root folder: {MN_ROOT}")
if not WRI_ROOT.exists():
    raise FileNotFoundError(f"Missing WRI root folder: {WRI_ROOT}")
# Out:
# SSI metrics CSV : F:\DEPRIMAP\DIRTY_MODEL\NATURE CITIES SUBMISSION FILES\cleangitrepo\citysegmentdeprivation\3_comparitive_analysis\SSI\Pooled_Results\ssi_rf_country_metrics.csv
# MN comparison   : F:\DEPRIMAP\DIRTY_MODEL\NATURE CITIES SUBMISSION FILES\cleangitrepo\citysegmentdeprivation\data_external\zenodo\mn_comparison_files
# WRI outputs     : F:\DEPRIMAP\DIRTY_MODEL\NATURE CITIES SUBMISSION FILES\cleangitrepo\citysegmentdeprivation\data_external\zenodo\wri_per_country_outputs
# Figure outdir   : F:\DEPRIMAP\DIRTY_MODEL\NATURE CITIES SUBMISSION FILES\cleangitrepo\citysegmentdeprivation\4_Figures_Tables\Figures

# %%
# --------------------------------------------------------------
# 2️⃣ Load and prepare SSI (SpaceDef, τ = 0.1)
# --------------------------------------------------------------
ssi_df = pd.read_csv(SSI_CSV)

# keep only τ = 0.1 and SpaceDef-only rule
ssi_df = ssi_df[ssi_df["τ (threshold)"] == 0.1].copy()
ssi_df = ssi_df[ssi_df["Rule / Comparison"] == "SSI (SpaceDef only)"].copy()
ssi_df["Rule"] = "SpaceDef"

ssi_long = ssi_df.melt(
    id_vars=["country", "Rule"],
    value_vars=["precision", "recall", "F1"],
    var_name="Metric",
    value_name="Score",
)
ssi_long["Metric"] = ssi_long["Metric"].str.capitalize()
ssi_long["Dataset"] = "SSI"

# %%
# --------------------------------------------------------------
# 3️⃣ Load and prepare MN (mn_label, mn_maj_thr = 0.1)
# --------------------------------------------------------------
mn_rows = []

for country_dir in sorted(MN_ROOT.glob("*")):
    if not country_dir.is_dir():
        continue

    country = country_dir.name

    # your current naming convention still fine
    fpath = country_dir / f"{country}_segments_mnlabels_k3_maj10.gpkg"
    if not fpath.exists():
        continue

    try:
        gdf = gpd.read_file(fpath)
    except Exception as e:
        print(f"❌ Read failed: {country} -> {e}")
        continue

    # required cols in YOUR files
    required = ["rf_label", "mn_label"]
    if any(c not in gdf.columns for c in required):
        print(f"⚠️ Missing required cols in {country}: need {required}, have {list(gdf.columns)}")
        continue

    # enforce threshold = 0.1 if present
    if "mn_maj_thr" in gdf.columns:
        gdf = gdf[pd.to_numeric(gdf["mn_maj_thr"], errors="coerce") == 0.1].copy()

    sub = gdf[["rf_label", "mn_label"]].dropna()
    if sub.empty:
        continue

    y_true = sub["rf_label"].astype(int)   # CSMD / RF as reference
    y_pred = sub["mn_label"].astype(int)   # MN as comparison

    mn_rows.append({
        "country": country,
        "tau": 0.1,
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "recall":    recall_score(y_true, y_pred, zero_division=0),
        "F1":        f1_score(y_true, y_pred, zero_division=0),
    })

mn_df = pd.DataFrame(mn_rows)

if mn_df.empty:
    raise RuntimeError("MN metrics table is empty. Check file paths and whether mn_maj_thr==0.1 exists in the files.")

mn_long = mn_df.melt(
    id_vars=["country", "tau"],
    value_vars=["precision", "recall", "F1"],
    var_name="Metric",
    value_name="Score",
)
mn_long["Metric"] = mn_long["Metric"].str.capitalize()
mn_long["Dataset"] = "MN"

print(f"✅ Built MN metrics for {len(mn_df)} countries")
# Out:
# ✅ Built MN metrics for 45 countries

# %%
# --------------------------------------------------------------
# 4️⃣ Load and prepare WRI (p_informal, τ = 0.1 only)
# --------------------------------------------------------------
wri_frames = []
for c_dir in sorted(WRI_ROOT.glob("*")):
    if not c_dir.is_dir():
        continue
    country = c_dir.name
    f = c_dir / f"{country}_wri_vs_rf_threshold_sweep_country.csv"
    if not f.exists():
        continue

    try:
        df = pd.read_csv(f)
        df.insert(0, "country", country)
        wri_frames.append(df)
    except Exception:
        continue

if not wri_frames:
    raise RuntimeError("No WRI sweep files found under PerCountry_Outputs.")

wri_df = pd.concat(wri_frames, ignore_index=True)

def _rule_key(x: str):
    if isinstance(x, str) and "p_informal" in x.lower():
        return "p_informal"
    return None

wri_df["Rule_key"] = wri_df["Rule / Comparison"].map(_rule_key)
wri_df = wri_df[wri_df["Rule_key"] == "p_informal"].copy()

wri_df.rename(columns={"τ (threshold)": "tau"}, inplace=True)
wri_df = wri_df[wri_df["tau"] == 0.1].copy()

wri_long = wri_df.melt(
    id_vars=["country", "tau"],
    value_vars=["precision", "recall", "F1"],
    var_name="Metric",
    value_name="Score",
)
wri_long["Metric"] = wri_long["Metric"].str.capitalize()
wri_long["Dataset"] = "WRI"

# %%
# --------------------------------------------------------------
# 5️⃣ Combine datasets for unified plotting
# --------------------------------------------------------------
combined = pd.concat([ssi_long, mn_long, wri_long], ignore_index=True)

metrics_order = ["Precision", "Recall", "F1"]
datasets = ["SSI", "MN", "WRI"]

# %%
# --------------------------------------------------------------
# 6️⃣ Palette and hard-coded global summaries
# --------------------------------------------------------------
gray_color = "#bdbdbd"

# NOTE: The summary dictionary below is HARD-CODED but derived from:
#   - rf_ssi_population_summary_GLOBAL_rule_threshold_table_millions.csv
#   - mn_rf_summary_segments_population_GLOBAL_k_tau_table_millions.csv
#   - wri_rf_population_summary_GLOBAL_rule_threshold_table_millions.csv
#
# WRI values updated to reflect corrected Zenodo per-block workflow
# (all cities per country, correct GLOBAL-row exclusion from aggregation).

summary = {
    "SSI": {
        "Segments":   {"CSMD": 54.6, "SpaceDef": 43.2},
        "Population": {"CSMD": 46.7, "SpaceDef": 42.6},
    },
    "MN": {
        "Segments":   {"CSMD": 55.8, "τ=0.1": 29.8},
        "Population": {"CSMD": 48.6, "τ=0.1": 40.9},
    },
    "WRI": {
        "Segments":   {"CSMD": 26.0, "τ=0.1": 43.2},
        "Population": {"CSMD": 24.4, "τ=0.1": 43.2},
    },
}

row_titles = [
    "Country-level alignment of SSI (SpaceDef) (τ = 0.1) with CSMD (n = 33)",
    "Country-level alignment of MN (k > 3, τ = 0.1) with CSMD (n = 45)",
    "Country-level alignment of WRI (p_informal, τ = 0.1) with CSMD (n = 48)",
]

# %% [markdown]
# > **Note on hard-coded summary values**
# >
# > The `summary` dictionary in the next cell contains precomputed global-level
# > deprivation percentages that are hard-coded. These values were derived from the
# > following global summary CSVs, which are committed to the repository:
# >
# > - `3_comparitive_analysis/SSI/Pooled_Results/rf_ssi_population_summary_GLOBAL_rule_threshold_table_millions.csv`
# > - `3_comparitive_analysis/MN/Outputs/mn_rf_summary_segments_population_GLOBAL_k_tau_table_millions.csv`
# > - `3_comparitive_analysis/WRI/Outputs/wri_rf_population_summary_GLOBAL_rule_threshold_table_millions.csv`
# >
# > For full reproducibility, future cleanup should replace the hard-coded values
# > by reading these CSVs directly and filtering to the appropriate rule and threshold row.

# %%
# --------------------------------------------------------------
# 7️⃣ Figure layout + Nature-friendly PDF settings
# --------------------------------------------------------------
sns.set_theme(
    context="paper",
    style="white",
    rc={
        "axes.edgecolor": "0.4",
        "axes.linewidth": 0.8,
        "axes.labelsize": 11,
        "font.size": 10,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
    },
)

mpl.rcParams["font.family"] = "DejaVu Sans"
mpl.rcParams["pdf.fonttype"] = 42
mpl.rcParams["ps.fonttype"]  = 42

fig = plt.figure(figsize=(13, 10))
gs = GridSpec(
    3,
    4,
    figure=fig,
    width_ratios=[1, 1, 1, 1.3],
    wspace=0.35,
    hspace=0.45,
)

axes = np.empty((3, 4), dtype=object)
for r in range(3):
    for c in range(4):
        axes[r, c] = fig.add_subplot(gs[r, c])

# --------------------------------------------------------------
# 8️⃣ Boxplots (left 3 columns)
# --------------------------------------------------------------
for r, dataset in enumerate(datasets):
    for c, metric in enumerate(metrics_order):
        ax = axes[r, c]

        sub = combined[
            (combined["Dataset"] == dataset)
            & (combined["Metric"] == metric)
        ].copy()

        ax.axhline(0.5, lw=0.7, ls="--", color="#bdbdbd", zorder=0)

        sns.boxplot(
            data=sub,
            y="Score",
            color=gray_color,
            width=0.50,
            whis=(5, 95),
            showfliers=False,
            boxprops=dict(linewidth=0.9, edgecolor="0.4"),
            whiskerprops=dict(linewidth=0.8, color="0.4"),
            medianprops=dict(linewidth=2.0, color="black"),
            capprops=dict(linewidth=0.8, color="0.4"),
            ax=ax,
        )

        # Scatter overlay + median label
        vals = sub["Score"].dropna()
        if len(vals) > 0:
            x_vals = np.random.normal(0, 0.05, size=len(vals))
            ax.scatter(
                x_vals,
                vals,
                s=14,
                color="black",
                alpha=0.6,
                edgecolor="white",
                linewidth=0.3,
                zorder=3,
            )
            m = vals.median()
            ax.text(
                0.26,
                m + 0.01,
                f"{m:.2f}",
                va="center",
                ha="left",
                fontsize=9.5,
                color="#222222",
                fontweight="bold",
            )

        ax.set_ylim(0, 1.02)
        ax.set_xlabel("")
        ax.set_ylabel(metric)
        ax.set_xticks([0])

        xtlab = "SpaceDef" if dataset == "SSI" else "τ = 0.1"
        ax.set_xticklabels([xtlab])
        sns.despine(ax=ax)

    # Row-level title centred over the three boxplots
    mid_ax = axes[r, 1]
    mid_ax.set_title(row_titles[r], fontsize=11.5, fontweight="bold", pad=15)

# --------------------------------------------------------------
# 9️⃣ Right column — metrics summary bars
# --------------------------------------------------------------
for r, dataset in enumerate(datasets):
    ax = axes[r, 3]
    ax.set_xlim(0, 60)
    ax.set_xticks([0, 20, 40, 60])
    ax.set_yticks([])
    ax.set_xlabel("%", fontsize=9)
    sns.despine(ax=ax, left=True, bottom=True)

    if r == 0:
        fig.text(
            0.805,
            0.978,
            "Metrics summary",
            ha="center",
            va="bottom",
            fontsize=11.5,
            fontweight="bold",
        )

    groups = list(summary[dataset].keys())  # ["Segments", "Population"]
    y_base = np.linspace(1.45, 0.55, len(groups))
    bar_height = 0.22

    for y0, group in zip(y_base, groups):
        metrics_dict = summary[dataset][group]

        for j, (label, val) in enumerate(metrics_dict.items()):
            y_pos = y0 - j * bar_height

            ax.barh(
                y_pos,
                val,
                height=bar_height * 0.75,
                color=gray_color,
                edgecolor="0.4",
                linewidth=0.6,
                zorder=2,
            )

            ax.text(
                val + 1.2,
                y_pos,
                f"{val:.1f}%",
                va="center",
                ha="left",
                fontsize=8.5,
                color="#222222",
            )

            ax.text(
                2,
                y_pos,
                label,
                va="center",
                ha="left",
                fontsize=7.5,
                color="#111111",
                fontweight="bold",
                zorder=3,
            )

        label_text = "Deprived\npopulation" if "Pop" in group else "Deprived\nsegments"
        ax.text(
            -5,
            y0 - (bar_height * 0.5),
            label_text,
            fontsize=7.5,
            rotation=90,
            fontweight="bold",
            ha="center",
            va="center",
        )

# --------------------------------------------------------------
# 🔟 Final layout and save (PDF)
# --------------------------------------------------------------
plt.subplots_adjust(left=0.08, right=0.94, top=0.96, bottom=0.06)

outfile_pdf = FIG_OUT_DIR / "Figure5_ThreeComparisons_withreg.pdf"
outfile_png = FIG_OUT_DIR / "Figure5_ThreeComparisons_withreg.png"
fig.savefig(outfile_pdf, format="pdf", bbox_inches="tight")
fig.savefig(outfile_png, format="png", dpi=600, bbox_inches="tight")
print(f"✅ Combined comparison figure saved to: {outfile_pdf}")

plt.show()
# Out:
# ✅ Combined comparison figure saved to: F:\DEPRIMAP\DIRTY_MODEL\NATURE CITIES SUBMISSION FILES\cleangitrepo\citysegmentdeprivation\4_Figures_Tables\Figures\Figure5_ThreeComparisons_withreg.pdf
