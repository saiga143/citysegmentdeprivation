# %% [markdown]
# # SSI Notebook A — Per-country clipping to city blocks
#
# ## Purpose
#
# For one country at a time:
# 1. Read the 5-band SSI pack raster.
# 2. Read the country's city-segment GeoPackage (RF prediction output).
# 3. Reproject city segments to raster CRS.
# 4. Clip SSI raster to the union of all city polygons.
#
# ## Output (used directly by `03_ssi_rf_comparison.ipynb`)
#
# ```
# data_external/zenodo/ssi_clipped/{country}/SSIpack100m_clipped_to_city_blocks_SIGNAL.tif
# ```
#
# ## Data requirements
#
# - **SSI raw rasters** (`data_external/ssi_raw/`): Exported from GEE via
#   `01_SSI_DataRetrieval.js` or downloaded from Zenodo. Large (~100 MB per country)
#   — not committed to GitHub.
# - **RF prediction GPKGs** (`data_external/zenodo/predictions/`): Per-country GPKG
#   files from the Zenodo deposit — not committed to GitHub.
# - **Clipped output rasters** (`data_external/zenodo/ssi_clipped/`): Written by this
#   notebook. Large — excluded from GitHub.
#
# ## Execution
#
# This notebook is designed to be run **once per country**. Update the `COUNTRY`
# variable in the CONFIG cell below and re-run for each of the 33 SSI-covered
# countries. Do not automate the country loop in this step — per-country outputs
# should be inspected for spatial coverage before running the comparison notebook.

# %%
from pathlib import Path
import geopandas as gpd
import rasterio as rio
from rasterio import mask as rio_mask
from shapely.ops import unary_union

# %%
from pathlib import Path

# ============================================================
# PATH CONFIGURATION  (portable — no hard-coded local paths)
# ============================================================
REPO_ROOT = Path.cwd()
while REPO_ROOT.name != "citysegmentdeprivation" and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent

DATA_EXTERNAL       = REPO_ROOT / "data_external"
ZENODO_DATA         = DATA_EXTERNAL / "zenodo"

PREDICTIONS_DIR     = ZENODO_DATA / "predictions"
SSI_RAW_DIR         = DATA_EXTERNAL / "ssi_raw"
SSI_CLIPPED_DIR     = ZENODO_DATA / "ssi_clipped"
SSI_OUTPUT_DIR      = REPO_ROOT / "3_comparitive_analysis" / "SSI" / "Pooled_Results"
SSI_PER_COUNTRY_DIR = SSI_OUTPUT_DIR / "per_country"
SSI_FIGURE_DIR      = SSI_OUTPUT_DIR / "Figures"

SSI_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
SSI_PER_COUNTRY_DIR.mkdir(parents=True, exist_ok=True)
SSI_FIGURE_DIR.mkdir(parents=True, exist_ok=True)

print("SSI_RAW_DIR:    ", SSI_RAW_DIR)
print("PREDICTIONS_DIR:", PREDICTIONS_DIR)
print("SSI_CLIPPED_DIR:", SSI_CLIPPED_DIR)

# %% [markdown]
# # 1️⃣ CONFIG — EDIT FOR EACH COUNTRY
#
# Repeat for each of the 33 countries to generate the files that are present in the folder '3_comparitive_analysis/SSI/PerCountry_Outputs/{country}'

# %%
# ============================================================
# CONFIG — update COUNTRY for each country you process
# ============================================================

# Country name (lowercase, underscore-separated — matches GPKG filename stem)
COUNTRY = "burundi"

# SSI raster filename stem — matches the name exported by 01_SSI_DataRetrieval.js.
# The GEE sanitize() function replaces non-alphanumeric chars with '_' and title-cases
# the country name from AfriShp. Adjust if the exported filename differs
# (e.g. "Cote_d_Ivoire" rather than "Burundi").
SSI_FILENAME_STEM = "Burundi"  # <-- update for each country

# (A) SSI raw raster for this country  (data_external/ssi_raw/ — not in GitHub)
SSI_TIF_PATH = SSI_RAW_DIR / f"{SSI_FILENAME_STEM}_SSIpack100m.tif"

# (B) RF prediction GPKG for this country  (data_external/zenodo/predictions/ — not in GitHub)
CITY_GPKG_PATH = PREDICTIONS_DIR / f"{COUNTRY}_rf_preds.gpkg"

# (C) Output folder for the clipped SSI raster  (data_external/zenodo/ssi_clipped/ — not in GitHub)
OUT_DIR = SSI_CLIPPED_DIR / COUNTRY
OUT_DIR.mkdir(parents=True, exist_ok=True)

CITY_COL = "UC_NM_MN"

print("SSI_TIF_PATH:  ", SSI_TIF_PATH)
print("CITY_GPKG_PATH:", CITY_GPKG_PATH)
print("OUT_DIR:       ", OUT_DIR)

# %% [markdown]
# # 2️⃣ Load city blocks and dissolve polygons per city

# %%
gdf = gpd.read_file(CITY_GPKG_PATH)
gdf = gdf[~gdf.geometry.is_empty & gdf.geometry.notna()].copy()
gdf["geometry"] = gdf.geometry.buffer(0)

# dissolve segments → one multipolygon per city
cities = gdf[[CITY_COL, "geometry"]].dissolve(by=CITY_COL, as_index=False)

# %% [markdown]
# # 3️⃣ Open SSI raster & reproject city polygons

# %%
with rio.open(SSI_TIF_PATH) as ds:
    r_crs = ds.crs
    bands = ds.descriptions or ()
    nodatas = ds.nodatavals

# define SSI band index
if bands and "SSI" in bands:
    SSI_BAND = bands.index("SSI") + 1
else:
    # assumed fallback order: [Water, Sanitation, Housing, SpaceDef, SSI]
    SSI_BAND = 5

# if nodata missing → assign default
if all(v is None for v in nodatas):
    default_nodata = 255 if "uint" in ds.dtypes[0] else -32768
    nodata_per_band = [default_nodata] * ds.count
else:
    default_nodata = 255 if "uint" in ds.dtypes[0] else -32768
    nodata_per_band = [
        v if v is not None else default_nodata
        for v in nodatas
    ]

# align CRS
cities_r = cities.to_crs(r_crs)

# union geometry of all cities
union_geom = unary_union(cities_r.geometry)

# %% [markdown]
# # 4️⃣ Clip SSI raster to union of cities

# %%
with rio.open(SSI_TIF_PATH) as ds:
    out_img, out_transform = rio_mask.mask(
        ds,
        [union_geom.__geo_interface__],
        crop=True,
        filled=True,
        nodata=nodata_per_band[0]
    )

    out_meta = ds.meta.copy()
    out_meta.update({
        "height": out_img.shape[1],
        "width": out_img.shape[2],
        "transform": out_transform,
        "count": ds.count,
        "nodata": nodata_per_band[0],
        "compress": "LZW"
    })

    out_tif = OUT_DIR / "SSIpack100m_clipped_to_city_blocks_SIGNAL.tif"

    with rio.open(out_tif, "w", **out_meta) as dst:
        for b in range(ds.count):
            dst.write(out_img[b].astype(ds.dtypes[b]), b + 1)
            # keep band descriptions
            desc = ds.descriptions[b] if ds.descriptions else None
            if desc:
                dst.set_band_description(b + 1, desc)

print("✅ Wrote:", out_tif)
